# %% [markdown]
# # Theory:
#
# <hr>
#
# <p>
#     <font color="tomato">
#         Volume Weighted Average Price [VWAP]:
#     </font>
#     <br>
#
#     It a technique used by stock traders to reduce the noise and find out the actual trends,
#     considering factors such as Volume and Rate.
# </p>
#
#
# <p>
#     <font color="tomato">
#         Auto Regressive Integrated Moving Average [ARIMA]:
#     </font>
#     <br>
#
#     ARIMA is a very popular statistical method for time series forecasting.
#     ARIMA models take into account the past values to predict the future values.
#
#     There are three important parameters in ARIMA:
#         - p (past values used for forecasting the next value)
#         - q (past forecast errors used to predict the future values)
#         - d (order of differencing)
# </p>

# %% [markdown]
# ## Dataset:
# <hr>
#
# <p>
#     Dataset collected from National Stock Exchange [NSE].
#     Link: https://www.nseindia.com/products/content/equities/equities/eq_security.htm
# </p>

# %% [markdown]
# # Code:
# <hr>

# %% [markdown]
# ### Global Variables:

# %%
rmseStock = {}

# %% [markdown]
# ### Imports and Global Settings:

# %%
# import packages### Helper Functions:
import numpy as np
import pandas as pd

# to plot charts and figures
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Matplotlib setting to adjust the plot size
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20,10

# %%
# Importing the ARIMA Library
from pmdarima.arima import auto_arima

# %%
# Data Normalisation
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

# %% [markdown]
# ### Helper Functions:

# %%
# Read the Dataset
def readCSV(filename):
    filename = "Dataset\\" + filename + ".csv"
    df = pd.read_csv(filename)
    df = cleanDate(df)
    return df    


# Changing the date to a standard format [dd-mm-yy]
def cleanDate(df):
    df['Date'] = pd.to_datetime(df.Date,format='%d-%b-%Y')
    df.index = df['Date']
    return df
    

#     Helper function to plot VWAP for stocks
def plotChart(df):
    plt.figure(figsize=(24, 8))
    plt.plot(df['Average Price'], label='VWAP')
    plt.xlabel("Date")
    plt.ylabel("Volume Weighted Average Price")
    plt.legend()
    
    
# Print the entire dataset
def printEntireData(df):
    print(df)
    plotChart(df)
    

# Print a sample of the dataset
def printSampleData(df):
    length = len(df)
    list = [0, 5, 6, 9, 10]
    df1 = df[0:5]
    print(df1[df1.columns[list]])
    print(".\n.\n.")
    df2 = df[987:]
    print(df2[df2.columns[list]])
    print("\nDisplaying 10 out of {} rows.".format(length))

# %% [markdown]
# ## Implementation of ARIMA model:
#
# <hr>

# %%
def arimaModel(df, stock):
    data = df.sort_index(ascending=True, axis=0)

    # Total data: 992
    endTrainingValue = 962
    train = data[:endTrainingValue]
    valid = data[endTrainingValue:]

    predictionPeriod = len(data) - len(train)

    training = train['Average Price']
    validation = valid['Average Price']

    model = auto_arima(training, start_p=1, start_q=1, max_p=3, max_q=3, m=12, start_P=0, seasonal=True, d=1, D=1, trace=True, error_action='ignore', suppress_warnings=True)
    model.fit(training)

    forecast = model.predict(n_periods = predictionPeriod)
    forecast = pd.DataFrame(forecast, index = valid.index,columns=['Prediction'])

    arimaModelError(valid, forecast, stock)
    plotResult(train, valid, forecast)

# %%
# Generating Root Mean Square Error (RMSE):
def arimaModelError(valid, forecast, stock):
    rms = np.sqrt(np.mean(np.power((np.array(valid['Average Price'])-np.array(forecast['Prediction'])),2)))
    print("Root Mean Square Error: {}".format(rms))
    rmseStock[stock] = rms

# %%
# Helper Function to Plot the result of the ARIMA model
def plotResult(train, valid, forecast):
    plt.figure(figsize=(24, 6))
    plt.plot(train['Average Price'], label = "Training Data VWAP")
    plt.plot(valid['Average Price'], label = "Validation Data VWAP")
    plt.plot(forecast['Prediction'], label = "Predicted VWAP")
    plt.legend()

# %% [markdown]
# ### Reading the Dataset & Executing Models:

# %%
# "BIOCON.csv"
# "COALINDIA.csv"
# "HEIDELBERG.csv"
# "ICICIBANK.csv"
# "MARUTI.csv"
# "PVR.csv"
# "SBIN.csv"

stockList = ['BIOCON', 'COALINDIA', 'HEIDELBERG', 'ICICIBANK', 'MARUTI', 'PVR', 'SBIN']

for stock in stockList:
    df = readCSV(stock)
    printSampleData(df)

    # Applying Arima Model
    print("Applying ARIMA Model on: {}".format(stock))
    arimaModel(df, stock)
# Out:
#             Symbol  High Price  Low Price  Average Price   Volume
# Date
# 2015-04-13  BIOCON      491.80     468.15         481.59  2337764
# 2015-04-15  BIOCON      495.70     474.45         486.89  1367669
# 2015-04-16  BIOCON      482.40     463.00         470.99   917630
# 2015-04-17  BIOCON      476.25     463.25         470.79   644312
# 2015-04-20  BIOCON      469.90     445.40         456.25  1160262
# .
# .
# .
#             Symbol  High Price  Low Price  Average Price   Volume
# Date
# 2019-04-05  BIOCON      615.75     610.10         612.58   622322
# 2019-04-08  BIOCON      616.50     605.50         609.09   769326
# 2019-04-09  BIOCON      619.90     603.55         614.15  1624259
# 2019-04-10  BIOCON      636.75     613.80         627.68  2419841
#
# Displaying 10 out of 991 rows.
# Applying ARIMA Model on: BIOCON
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=8875.759, BIC=8900.036, Fit time=2.685 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=9490.241, BIC=9499.952, Fit time=0.075 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=9193.270, BIC=9212.691, Fit time=1.114 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=8873.894, BIC=8893.315, Fit time=1.274 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=8875.872, BIC=8900.149, Fit time=1.980 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=9490.854, BIC=9505.420, Fit time=0.385 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=8875.882, BIC=8900.159, Fit time=4.164 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=8877.877, BIC=8907.010, Fit time=4.377 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=8872.519, BIC=8887.085, Fit time=2.073 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 1, 1, 12); AIC=8874.514, BIC=8893.935, Fit time=1.447 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 2, 12); AIC=8874.520, BIC=8893.942, Fit time=3.551 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 1, 2, 12); AIC=8872.658, BIC=8896.935, Fit time=8.758 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=8873.921, BIC=8893.343, Fit time=1.292 seconds
# Total fit time: 33.193 seconds
# Root Mean Square Error: 10.760898111763032
#                Symbol  High Price  Low Price  Average Price   Volume
# Date
# 2015-04-13  COALINDIA      395.70     383.80         391.38  2909461
# 2015-04-15  COALINDIA      391.70     384.00         387.48  4149634
# 2015-04-16  COALINDIA      386.05     381.60         383.62  2034424
# 2015-04-17  COALINDIA      385.15     379.05         381.81  2106426
# 2015-04-20  COALINDIA      382.75     370.55         374.19  3400318
# .
# .
# .
#                Symbol  High Price  Low Price  Average Price   Volume
# Date
# 2019-04-05  COALINDIA       236.2      233.7         234.73  3044309
# 2019-04-08  COALINDIA       236.2      231.6         233.66  4374595
# 2019-04-09  COALINDIA       239.5      232.3         236.70  9383394
# 2019-04-10  COALINDIA       242.9      238.4         240.90  8657560
#
# Displaying 10 out of 991 rows.
# Applying ARIMA Model on: COALINDIA
# C:\Users\Kanishk\Anaconda3\envs\tf_gpu\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=5512.129, BIC=5536.406, Fit time=3.609 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=6125.402, BIC=6135.112, Fit time=0.090 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=5820.139, BIC=5839.561, Fit time=1.224 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=5519.608, BIC=5539.030, Fit time=2.163 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=5513.632, BIC=5542.765, Fit time=4.813 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=6092.631, BIC=6112.053, Fit time=0.544 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=5513.678, BIC=5542.811, Fit time=18.066 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=5510.072, BIC=5544.060, Fit time=11.828 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=5518.184, BIC=5547.317, Fit time=8.650 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=5511.659, BIC=5550.502, Fit time=18.375 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 2, 12); AIC=5521.988, BIC=5551.121, Fit time=8.483 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=5511.698, BIC=5550.541, Fit time=15.132 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 1, 2, 12); AIC=5542.755, BIC=5567.032, Fit time=6.634 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=5514.073, BIC=5557.771, Fit time=21.774 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 1, 2, 12); AIC=5509.602, BIC=5548.445, Fit time=15.097 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 1, 1, 12); AIC=5513.369, BIC=5547.357, Fit time=12.984 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(2, 1, 2, 12); AIC=5517.153, BIC=5551.141, Fit time=10.357 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(2, 1, 2, 12); AIC=5511.128, BIC=5554.826, Fit time=18.690 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(2, 1, 2, 12); AIC=5520.968, BIC=5554.956, Fit time=9.567 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(2, 1, 2, 12); AIC=5511.166, BIC=5554.865, Fit time=16.587 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(2, 1, 2, 12); AIC=5541.813, BIC=5570.946, Fit time=7.335 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(2, 1, 2, 12); AIC=5513.591, BIC=5562.146, Fit time=22.943 seconds
# Total fit time: 234.978 seconds
# Root Mean Square Error: 20.917941232112238
#                 Symbol  High Price  Low Price  Average Price  Volume
# Date
# 2015-04-13  HEIDELBERG       80.85      78.35          79.99  189183
# 2015-04-15  HEIDELBERG       81.75      78.05          79.86  201172
# 2015-04-16  HEIDELBERG       79.50      77.50          78.31  124294
# 2015-04-17  HEIDELBERG       78.40      74.60          75.84  198961
# 2015-04-20  HEIDELBERG       75.45      70.70          72.05  374017
# .
# .
# .
#                 Symbol  High Price  Low Price  Average Price  Volume
# Date
# 2019-04-05  HEIDELBERG       183.4     179.05         181.56  277564
# 2019-04-08  HEIDELBERG       182.4     179.05         180.81  157441
# 2019-04-09  HEIDELBERG       181.0     175.90         177.60  138895
# 2019-04-10  HEIDELBERG       179.9     175.45         177.81  125385
#
# Displaying 10 out of 991 rows.
# Applying ARIMA Model on: HEIDELBERG
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=5264.299, BIC=5274.010, Fit time=0.094 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=4950.426, BIC=4969.847, Fit time=0.981 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=4618.536, BIC=4637.958, Fit time=4.347 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=4619.517, BIC=4643.794, Fit time=3.715 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=5259.031, BIC=5273.597, Fit time=0.309 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=4619.578, BIC=4643.855, Fit time=11.480 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=4620.587, BIC=4649.720, Fit time=10.616 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=4625.845, BIC=4640.412, Fit time=2.211 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=4613.613, BIC=4637.890, Fit time=4.163 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(0, 1, 1, 12); AIC=4613.643, BIC=4647.631, Fit time=5.812 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=4614.919, BIC=4644.052, Fit time=5.025 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 0, 12); AIC=5247.669, BIC=5267.090, Fit time=0.383 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 2, 12); AIC=4614.957, BIC=4644.090, Fit time=15.052 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=4616.247, BIC=4650.235, Fit time=12.585 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=4611.934, BIC=4641.067, Fit time=2.931 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(0, 1, 1, 12); AIC=4612.878, BIC=4651.721, Fit time=9.536 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=4613.466, BIC=4647.454, Fit time=4.942 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 0, 12); AIC=5205.973, BIC=5230.250, Fit time=0.994 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 2, 12); AIC=4613.495, BIC=4647.483, Fit time=11.825 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=4614.285, BIC=4653.129, Fit time=11.395 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=4612.741, BIC=4646.729, Fit time=8.988 seconds
# Total fit time: 127.399 seconds
# Root Mean Square Error: 27.680386431353806
#                Symbol  High Price  Low Price  Average Price    Volume
# Date
# 2015-04-13  ICICIBANK      319.90     316.00         317.58   8009699
# 2015-04-15  ICICIBANK      322.30     313.05         319.49  10270686
# 2015-04-16  ICICIBANK      316.00     310.15         312.63   8802458
# 2015-04-17  ICICIBANK      314.95     308.25         310.21  10581425
# 2015-04-20  ICICIBANK      317.60     308.30         313.50  10603355
# .
# .
# .
#                Symbol  High Price  Low Price  Average Price    Volume
# Date
# 2019-04-05  ICICIBANK      392.50     385.60         388.82  10853927
# 2019-04-08  ICICIBANK      391.45     385.00         388.41   6305407
# 2019-04-09  ICICIBANK      398.35     387.15         392.60  13206348
# 2019-04-10  ICICIBANK      398.80     392.70         395.63  14000018
#
# Displaying 10 out of 991 rows.
# Applying ARIMA Model on: ICICIBANK
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=5803.409, BIC=5827.686, Fit time=2.706 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=6421.396, BIC=6431.107, Fit time=0.088 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=6138.800, BIC=6158.221, Fit time=1.098 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=5807.116, BIC=5826.538, Fit time=3.639 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=5805.351, BIC=5834.484, Fit time=5.449 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=6355.029, BIC=6374.451, Fit time=1.106 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=5805.349, BIC=5834.482, Fit time=14.488 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=5806.696, BIC=5840.684, Fit time=19.358 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=5808.571, BIC=5827.993, Fit time=3.902 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=5803.673, BIC=5832.806, Fit time=6.343 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=5823.494, BIC=5838.060, Fit time=3.355 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=5805.522, BIC=5839.510, Fit time=4.035 seconds
# Total fit time: 65.581 seconds
# Root Mean Square Error: 34.54543039289545
#             Symbol  High Price  Low Price  Average Price  Volume
# Date
# 2015-04-13  MARUTI      3680.0    3642.75        3659.45  218690
# 2015-04-15  MARUTI      3729.0    3650.40        3697.64  232802
# 2015-04-16  MARUTI      3718.7    3662.25        3690.80  206305
# 2015-04-17  MARUTI      3682.9    3636.35        3660.63   99056
# 2015-04-20  MARUTI      3648.4    3584.60        3610.07  175033
# .
# .
# .
#             Symbol  High Price  Low Price  Average Price  Volume
# Date
# 2019-04-05  MARUTI     7143.95     7050.0        7102.19  729603
# 2019-04-08  MARUTI     7150.00     7044.7        7102.35  498374
# 2019-04-09  MARUTI     7235.00     7080.0        7155.98  741669
# 2019-04-10  MARUTI     7218.95     7144.6        7179.12  590107
#
# Displaying 10 out of 991 rows.
# Applying ARIMA Model on: MARUTI
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=11035.051, BIC=11059.328, Fit time=2.211 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=11681.612, BIC=11691.323, Fit time=0.089 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=11347.067, BIC=11366.488, Fit time=1.796 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=11034.070, BIC=11053.491, Fit time=1.750 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=11036.028, BIC=11060.305, Fit time=2.200 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=11634.035, BIC=11648.601, Fit time=0.458 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=11036.031, BIC=11060.308, Fit time=5.411 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=11036.317, BIC=11065.450, Fit time=21.616 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=11092.953, BIC=11107.519, Fit time=0.987 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=11035.101, BIC=11059.378, Fit time=2.238 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=11037.044, BIC=11066.177, Fit time=3.991 seconds
# Total fit time: 42.752 seconds
# Root Mean Square Error: 226.5332417447723
#            Symbol  High Price  Low Price  Average Price  Volume
# Date
# 2015-04-13    PVR       679.8      661.7         669.04   19009
# 2015-04-15    PVR       675.0      663.0         666.90   16250
# 2015-04-16    PVR       670.0      654.0         661.50   10192
# 2015-04-17    PVR       665.0      650.0         656.12   12223
# 2015-04-20    PVR       660.0      645.0         649.21    8804
# .
# .
# .
#            Symbol  High Price  Low Price  Average Price  Volume
# Date
# 2019-04-05    PVR     1682.05    1655.55        1667.41  281610
# 2019-04-08    PVR     1699.00    1669.70        1686.32  348832
# 2019-04-09    PVR     1687.00    1655.00        1671.04  255249
# 2019-04-10    PVR     1720.65    1670.00        1699.61  410044
#
# Displaying 10 out of 991 rows.
# Applying ARIMA Model on: PVR
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=8568.567, BIC=8592.844, Fit time=2.433 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=9144.716, BIC=9154.427, Fit time=0.086 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=8912.442, BIC=8931.863, Fit time=1.726 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=8567.819, BIC=8587.241, Fit time=1.652 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=8568.012, BIC=8592.289, Fit time=2.219 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=9136.379, BIC=9150.946, Fit time=0.600 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=8567.861, BIC=8592.138, Fit time=10.190 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=8569.743, BIC=8598.875, Fit time=16.901 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=8578.173, BIC=8592.739, Fit time=1.524 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=8568.374, BIC=8592.652, Fit time=1.707 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=8570.239, BIC=8599.371, Fit time=2.850 seconds
# Total fit time: 41.891 seconds
# Root Mean Square Error: 123.7182997418695
#            Symbol  High Price  Low Price  Average Price    Volume
# Date
# 2015-04-13   SBIN      288.50     283.35         285.79  11985436
# 2015-04-15   SBIN      294.45     285.95         290.52  17289500
# 2015-04-16   SBIN      294.25     286.50         290.52  15043998
# 2015-04-17   SBIN      294.90     289.20         292.12  16819018
# 2015-04-20   SBIN      293.35     284.85         289.82  13788536
# .
# .
# .
#            Symbol  High Price  Low Price  Average Price    Volume
# Date
# 2019-04-08   SBIN      319.25      311.1         314.81  17394139
# 2019-04-09   SBIN      315.70      308.1         311.80  25556039
# 2019-04-10   SBIN      317.05      310.0         313.54  19237974
# 2019-04-11   SBIN      315.40      308.7         312.15  14897935
#
# Displaying 10 out of 991 rows.
# Applying ARIMA Model on: SBIN
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=5633.361, BIC=5657.638, Fit time=4.600 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=6197.370, BIC=6207.081, Fit time=0.084 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=5931.304, BIC=5950.726, Fit time=1.119 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=5633.522, BIC=5652.944, Fit time=2.881 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=5625.968, BIC=5655.100, Fit time=5.849 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 0, 12); AIC=5924.768, BIC=5949.045, Fit time=1.718 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=5633.098, BIC=5667.086, Fit time=16.968 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=6142.210, BIC=6161.631, Fit time=0.442 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 1, 2, 12); AIC=5627.769, BIC=5666.612, Fit time=20.307 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=5625.325, BIC=5649.602, Fit time=4.319 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 1, 1, 12); AIC=5680.840, BIC=5700.261, Fit time=3.435 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=5626.133, BIC=5655.265, Fit time=5.480 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=5624.966, BIC=5658.954, Fit time=7.608 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=5633.938, BIC=5663.070, Fit time=4.001 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(2, 1, 1, 12); AIC=5627.240, BIC=5666.083, Fit time=20.595 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 0, 12); AIC=5900.894, BIC=5930.026, Fit time=7.134 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=5633.868, BIC=5672.711, Fit time=19.224 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 0, 12); AIC=6101.710, BIC=6125.987, Fit time=2.174 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(2, 1, 2, 12); AIC=5629.178, BIC=5672.877, Fit time=23.314 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=5626.807, BIC=5665.650, Fit time=8.117 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(1, 1, 1, 12); AIC=5626.930, BIC=5665.773, Fit time=9.499 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(1, 1, 1, 12); AIC=5621.750, BIC=5665.449, Fit time=15.627 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(0, 1, 1, 12); AIC=5631.190, BIC=5670.033, Fit time=7.633 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(2, 1, 1, 12); AIC=5625.507, BIC=5674.061, Fit time=22.735 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(1, 1, 0, 12); AIC=5870.169, BIC=5909.013, Fit time=8.168 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(1, 1, 2, 12); AIC=5632.638, BIC=5681.193, Fit time=29.322 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(0, 1, 0, 12); AIC=6080.494, BIC=6114.482, Fit time=4.100 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(2, 1, 2, 12); AIC=5626.132, BIC=5679.541, Fit time=32.721 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(1, 1, 1, 12); AIC=5620.127, BIC=5668.681, Fit time=11.767 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=5618.362, BIC=5662.060, Fit time=9.569 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=5627.040, BIC=5661.028, Fit time=4.460 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=5628.106, BIC=5666.949, Fit time=7.726 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(2, 1, 1, 12); AIC=5620.463, BIC=5669.017, Fit time=26.089 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(1, 1, 0, 12); AIC=5867.757, BIC=5906.601, Fit time=8.595 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=5628.254, BIC=5676.808, Fit time=23.694 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(0, 1, 0, 12); AIC=6048.315, BIC=6082.302, Fit time=2.617 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(2, 1, 2, 12); AIC=5619.762, BIC=5673.172, Fit time=29.002 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=5628.054, BIC=5666.897, Fit time=8.544 seconds
# Total fit time: 421.309 seconds
# Root Mean Square Error: 34.61767902339631

# %%
print(rmseStock)
# Out:
# {'BIOCON': 10.760898111763032, 'COALINDIA': 20.917941232112238, 'HEIDELBERG': 27.680386431353806, 'ICICIBANK': 34.54543039289545, 'MARUTI': 226.5332417447723, 'PVR': 123.7182997418695, 'SBIN': 34.61767902339631}

# %%
avgRMSE = 0

for i in rmseStock:
    avgRMSE = avgRMSE + rmseStock[i]

avgRMSE = avgRMSE/len(rmseStock)
avgRMSE
# Out:
# 68.39626809688038

# %% [markdown]
# ## Inference
