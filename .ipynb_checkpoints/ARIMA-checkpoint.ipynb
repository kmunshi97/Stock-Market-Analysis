# %% [markdown]
# # Theory:
#
# <hr>
#
# <p>
#     <font color="tomato">
#         Volume Weighted Average Price [VWAP]:
#     </font>
#     <br>
#
#     It a technique used by stock traders to reduce the noise and find out the actual trends,
#     considering factors such as Volume and Rate.
# </p>
#
#
# <p>
#     <font color="tomato">
#         Auto Regressive Integrated Moving Average [ARIMA]:
#     </font>
#     <br>
#
#     ARIMA is a very popular statistical method for time series forecasting.
#     ARIMA models take into account the past values to predict the future values.
#
#     There are three important parameters in ARIMA:
#         - p (past values used for forecasting the next value)
#         - q (past forecast errors used to predict the future values)
#         - d (order of differencing)
# </p>

# %% [markdown]
# ## Dataset:
# <hr>
#
# <p>
#     Dataset collected from National Stock Exchange [NSE].<br>
#     Link: https://www.nseindia.com/products/content/equities/equities/eq_security.htm
#
#     Companies:
#         - Biocon
#         - Britannia
#         - Coal India
#         - Eicher Motors
#         - Heidelberg
#         - ICICI Bank
#         - ITC
#         - Maruti
#         - Priya Village Roadshow (PVR)
#         - SBI
# </p>

# %% [markdown]
# # Code:
# <hr>

# %% [markdown]
# ### Global Variables:

# %%
rmseStock = {}

# %% [markdown]
# ### Imports and Global Settings:

# %%
# import packages### Helper Functions:
import numpy as np
import pandas as pd

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# to plot charts and figures
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Matplotlib setting to adjust the plot size
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20,10

# %%
# Importing the ARIMA Library
from pmdarima.arima import auto_arima

# %%
# Data Normalisation
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

# %% [markdown]
# ### Helper Functions:

# %%
# Read the Dataset
def readCSV(filename):
    filename = "Dataset\\" + filename + ".csv"
    df = pd.read_csv(filename)
    df = cleanDate(df)
    return df    


# Changing the date to a standard format [dd-mm-yy]
def cleanDate(df):
    df['Date'] = pd.to_datetime(df.Date,format='%d-%b-%Y')
    df.index = df['Date']
    return df
    

#     Helper function to plot VWAP for stocks
def plotChart(df):
    plt.figure(figsize=(24, 8))
    plt.plot(df['Average Price'], label='VWAP')
    plt.xlabel("Date")
    plt.ylabel("Volume Weighted Average Price")
    plt.legend()
    
    
# Print the entire dataset
def printEntireData(df):
    print(df)
    plotChart(df)
    

# Print a sample of the dataset
def printSampleData(df):
    length = len(df)
    list = [0, 5, 6, 9, 10]
    df1 = df[0:5]
    print(df1[df1.columns[list]])
    print(".\n.\n.")
    df2 = df[987:]
    print(df2[df2.columns[list]])
    print("\nDisplaying 10 out of {} rows.".format(length))

# %% [markdown]
# ## Implementation of ARIMA model:
#
# <hr>

# %%
def arimaModel(df, stock):
    data = df.sort_index(ascending=True, axis=0)

    # Total data: 992
    endTrainingValue = 962
    train = data[:endTrainingValue]
    valid = data[endTrainingValue:]

    predictionPeriod = len(data) - len(train)

    training = train['Average Price']
    validation = valid['Average Price']

    model = auto_arima(training, start_p=1, start_q=1, max_p=3, max_q=3, m=12, start_P=0, seasonal=True, d=1, D=1, trace=True, error_action='ignore', suppress_warnings=True)
    model.fit(training)

    forecast = model.predict(n_periods = predictionPeriod)
    forecast = pd.DataFrame(forecast, index = valid.index, columns=['Prediction'])

    arimaModelError(valid, forecast, stock)
    plotResult(train, valid, forecast, stock)

# %%
# Generating Root Mean Square Error (RMSE):
def arimaModelError(valid, forecast, stock):
    rms = np.sqrt(np.mean(np.power((np.array(valid['Average Price']) - np.array(forecast['Prediction'])),2)))
    print("Root Mean Square Error: {}".format(rms))
    rmseStock[stock] = rms

# %%
# Helper Function to Plot the result of the ARIMA model
def plotResult(train, valid, forecast, stock):
    plt.figure(figsize=(24, 6))
    plt.plot(train['Average Price'], label = "Training Data VWAP")
    plt.plot(valid['Average Price'], label = "Validation Data VWAP")
    plt.plot(forecast['Prediction'], label = "Predicted VWAP")
    plt.title(stock, fontsize = 18)
    plt.legend()

# %% [markdown]
# ### Reading the Dataset & Executing Models:

# %%
stockList = ['BIOCON', 'BRITANNIA', 'COALINDIA', 'EICHERMOT', 'HEIDELBERG', 'ICICIBANK', 'ITC','MARUTI', 'PVR', 'SBIN']

for stock in stockList:
    df = readCSV(stock)
    printSampleData(df)

    # Applying Arima Model
    print("Applying ARIMA Model on: {}".format(stock))
    arimaModel(df, stock)
# Out:
#             Symbol  High Price  Low Price  Average Price   Volume
# Date
# 2015-04-13  BIOCON      491.80     468.15         481.59  2337764
# 2015-04-15  BIOCON      495.70     474.45         486.89  1367669
# 2015-04-16  BIOCON      482.40     463.00         470.99   917630
# 2015-04-17  BIOCON      476.25     463.25         470.79   644312
# 2015-04-20  BIOCON      469.90     445.40         456.25  1160262
# .
# .
# .
#             Symbol  High Price  Low Price  Average Price   Volume
# Date
# 2019-04-05  BIOCON      615.75     610.10         612.58   622322
# 2019-04-08  BIOCON      616.50     605.50         609.09   769326
# 2019-04-09  BIOCON      619.90     603.55         614.15  1624259
# 2019-04-10  BIOCON      636.75     613.80         627.68  2419841
#
# Displaying 10 out of 991 rows.
# Applying ARIMA Model on: BIOCON
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=8875.759, BIC=8900.036, Fit time=5.180 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=9490.241, BIC=9499.952, Fit time=0.156 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=9193.270, BIC=9212.691, Fit time=2.137 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=8873.894, BIC=8893.315, Fit time=2.391 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=8875.872, BIC=8900.149, Fit time=3.735 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=9490.854, BIC=9505.420, Fit time=1.191 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=8875.882, BIC=8900.159, Fit time=9.445 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=8877.877, BIC=8907.010, Fit time=9.821 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=8872.519, BIC=8887.085, Fit time=4.844 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 1, 1, 12); AIC=8874.514, BIC=8893.935, Fit time=2.939 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 2, 12); AIC=8874.520, BIC=8893.942, Fit time=6.946 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 1, 2, 12); AIC=8872.658, BIC=8896.935, Fit time=21.025 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=8873.921, BIC=8893.343, Fit time=2.929 seconds
# Total fit time: 72.741 seconds
# Root Mean Square Error: 10.760898111763032
#                Symbol  High Price  Low Price  Average Price  Volume
# Date
# 2015-04-13  BRITANNIA      2320.0    2269.55        2296.01  277352
# 2015-04-15  BRITANNIA      2377.8    2316.00        2356.08  207468
# 2015-04-16  BRITANNIA      2375.0    2290.25        2325.80  161860
# 2015-04-17  BRITANNIA      2328.0    2295.00        2301.15  113874
# 2015-04-20  BRITANNIA      2330.0    2150.00        2188.55  262487
# .
# .
# .
#                Symbol  High Price  Low Price  Average Price  Volume
# Date
# 2019-04-09  BRITANNIA     2988.75     2942.5        2963.00  350181
# 2019-04-10  BRITANNIA     2995.00     2951.3        2964.52  377556
# 2019-04-11  BRITANNIA     2974.05     2940.0        2951.74  276801
# 2019-04-12  BRITANNIA     2990.00     2944.0        2970.17  261483
#
# Displaying 10 out of 991 rows.
# Applying ARIMA Model on: BRITANNIA
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=12253.631, BIC=12263.342, Fit time=0.230 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=11988.020, BIC=12007.442, Fit time=4.124 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=11666.110, BIC=11685.532, Fit time=3.238 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=11667.574, BIC=11691.851, Fit time=5.523 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=12255.437, BIC=12270.004, Fit time=0.667 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=11667.604, BIC=11691.881, Fit time=14.363 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=11666.669, BIC=11695.801, Fit time=18.120 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=11664.293, BIC=11678.859, Fit time=1.966 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 1, 1, 12); AIC=11665.763, BIC=11685.184, Fit time=3.241 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 2, 12); AIC=11665.789, BIC=11685.211, Fit time=8.344 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 1, 2, 12); AIC=11664.878, BIC=11689.155, Fit time=16.206 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=11666.089, BIC=11685.511, Fit time=2.841 seconds
# Total fit time: 78.872 seconds
# Root Mean Square Error: 104.02291331561547
#                Symbol  High Price  Low Price  Average Price   Volume
# Date
# 2015-04-13  COALINDIA      395.70     383.80         391.38  2909461
# 2015-04-15  COALINDIA      391.70     384.00         387.48  4149634
# 2015-04-16  COALINDIA      386.05     381.60         383.62  2034424
# 2015-04-17  COALINDIA      385.15     379.05         381.81  2106426
# 2015-04-20  COALINDIA      382.75     370.55         374.19  3400318
# .
# .
# .
#                Symbol  High Price  Low Price  Average Price   Volume
# Date
# 2019-04-05  COALINDIA       236.2      233.7         234.73  3044309
# 2019-04-08  COALINDIA       236.2      231.6         233.66  4374595
# 2019-04-09  COALINDIA       239.5      232.3         236.70  9383394
# 2019-04-10  COALINDIA       242.9      238.4         240.90  8657560
#
# Displaying 10 out of 991 rows.
# Applying ARIMA Model on: COALINDIA
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=5512.129, BIC=5536.406, Fit time=6.872 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=6125.402, BIC=6135.112, Fit time=0.156 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=5820.139, BIC=5839.561, Fit time=2.121 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=5519.608, BIC=5539.030, Fit time=4.155 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=5513.632, BIC=5542.765, Fit time=9.464 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=6092.631, BIC=6112.053, Fit time=1.031 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=5513.678, BIC=5542.811, Fit time=32.298 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=5510.072, BIC=5544.060, Fit time=20.145 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=5518.184, BIC=5547.317, Fit time=14.903 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=5511.659, BIC=5550.502, Fit time=28.143 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 2, 12); AIC=5521.988, BIC=5551.121, Fit time=14.101 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=5511.698, BIC=5550.541, Fit time=26.380 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 1, 2, 12); AIC=5542.755, BIC=5567.032, Fit time=11.963 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=5514.073, BIC=5557.771, Fit time=26.717 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 1, 2, 12); AIC=5509.602, BIC=5548.445, Fit time=14.505 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 1, 1, 12); AIC=5513.369, BIC=5547.357, Fit time=13.724 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(2, 1, 2, 12); AIC=5517.153, BIC=5551.141, Fit time=10.650 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(2, 1, 2, 12); AIC=5511.128, BIC=5554.826, Fit time=19.445 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(2, 1, 2, 12); AIC=5520.968, BIC=5554.956, Fit time=9.555 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(2, 1, 2, 12); AIC=5511.166, BIC=5554.865, Fit time=17.252 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(2, 1, 2, 12); AIC=5541.813, BIC=5570.946, Fit time=7.623 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(2, 1, 2, 12); AIC=5513.591, BIC=5562.146, Fit time=23.740 seconds
# Total fit time: 314.943 seconds
# Root Mean Square Error: 20.917941232112238
#                Symbol  High Price  Low Price  Average Price  Volume
# Date
# 2015-04-13  EICHERMOT     16231.0   16001.00       16123.94   43662
# 2015-04-15  EICHERMOT     16120.0   15810.00       15940.67   44445
# 2015-04-16  EICHERMOT     16240.0   15734.00       16007.99  108100
# 2015-04-17  EICHERMOT     15875.0   15199.95       15500.59   57568
# 2015-04-20  EICHERMOT     15310.0   14630.00       14789.72   90233
# .
# .
# .
#                Symbol  High Price  Low Price  Average Price  Volume
# Date
# 2019-04-10  EICHERMOT     21080.0   20650.00       20911.80   83550
# 2019-04-11  EICHERMOT     21073.9   20810.40       20980.04   97645
# 2019-04-12  EICHERMOT     21430.0   20905.05       21131.52  130351
#
# Displaying 10 out of 990 rows.
# Applying ARIMA Model on: EICHERMOT
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=14025.178, BIC=14049.455, Fit time=4.496 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=14713.172, BIC=14722.883, Fit time=0.094 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=14333.680, BIC=14353.102, Fit time=1.735 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=14023.209, BIC=14042.631, Fit time=2.111 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=14025.110, BIC=14049.387, Fit time=5.113 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=14621.961, BIC=14636.527, Fit time=0.246 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=14025.151, BIC=14049.428, Fit time=6.967 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=14027.060, BIC=14056.193, Fit time=9.698 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=14091.283, BIC=14105.849, Fit time=1.122 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=14025.180, BIC=14049.457, Fit time=5.709 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=14086.466, BIC=14115.599, Fit time=5.461 seconds
# Total fit time: 42.768 seconds
# Root Mean Square Error: 2110.138974384907
#                 Symbol  High Price  Low Price  Average Price  Volume
# Date
# 2015-04-13  HEIDELBERG       80.85      78.35          79.99  189183
# 2015-04-15  HEIDELBERG       81.75      78.05          79.86  201172
# 2015-04-16  HEIDELBERG       79.50      77.50          78.31  124294
# 2015-04-17  HEIDELBERG       78.40      74.60          75.84  198961
# 2015-04-20  HEIDELBERG       75.45      70.70          72.05  374017
# .
# .
# .
#                 Symbol  High Price  Low Price  Average Price  Volume
# Date
# 2019-04-05  HEIDELBERG       183.4     179.05         181.56  277564
# 2019-04-08  HEIDELBERG       182.4     179.05         180.81  157441
# 2019-04-09  HEIDELBERG       181.0     175.90         177.60  138895
# 2019-04-10  HEIDELBERG       179.9     175.45         177.81  125385
#
# Displaying 10 out of 991 rows.
# Applying ARIMA Model on: HEIDELBERG
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=5264.299, BIC=5274.010, Fit time=0.063 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=4950.426, BIC=4969.847, Fit time=0.918 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=4618.536, BIC=4637.958, Fit time=3.740 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=4619.517, BIC=4643.794, Fit time=3.433 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=5259.031, BIC=5273.597, Fit time=0.255 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=4619.578, BIC=4643.855, Fit time=10.082 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=4620.587, BIC=4649.720, Fit time=8.777 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=4625.845, BIC=4640.412, Fit time=2.048 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=4613.613, BIC=4637.890, Fit time=3.848 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(0, 1, 1, 12); AIC=4613.643, BIC=4647.631, Fit time=5.355 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=4614.919, BIC=4644.052, Fit time=4.624 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 0, 12); AIC=5247.669, BIC=5267.090, Fit time=0.345 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 2, 12); AIC=4614.957, BIC=4644.090, Fit time=14.325 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=4616.247, BIC=4650.235, Fit time=11.972 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=4611.934, BIC=4641.067, Fit time=3.185 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(0, 1, 1, 12); AIC=4612.878, BIC=4651.721, Fit time=9.322 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=4613.466, BIC=4647.454, Fit time=4.381 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 0, 12); AIC=5205.973, BIC=5230.250, Fit time=0.931 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 2, 12); AIC=4613.495, BIC=4647.483, Fit time=11.998 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=4614.285, BIC=4653.129, Fit time=11.641 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=4612.741, BIC=4646.729, Fit time=8.241 seconds
# Total fit time: 119.498 seconds
# Root Mean Square Error: 27.680386431353806
#                Symbol  High Price  Low Price  Average Price    Volume
# Date
# 2015-04-13  ICICIBANK      319.90     316.00         317.58   8009699
# 2015-04-15  ICICIBANK      322.30     313.05         319.49  10270686
# 2015-04-16  ICICIBANK      316.00     310.15         312.63   8802458
# 2015-04-17  ICICIBANK      314.95     308.25         310.21  10581425
# 2015-04-20  ICICIBANK      317.60     308.30         313.50  10603355
# .
# .
# .
#                Symbol  High Price  Low Price  Average Price    Volume
# Date
# 2019-04-05  ICICIBANK      392.50     385.60         388.82  10853927
# 2019-04-08  ICICIBANK      391.45     385.00         388.41   6305407
# 2019-04-09  ICICIBANK      398.35     387.15         392.60  13206348
# 2019-04-10  ICICIBANK      398.80     392.70         395.63  14000018
#
# Displaying 10 out of 991 rows.
# Applying ARIMA Model on: ICICIBANK
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=5803.409, BIC=5827.686, Fit time=2.400 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=6421.396, BIC=6431.107, Fit time=0.078 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=6138.800, BIC=6158.221, Fit time=1.074 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=5807.116, BIC=5826.538, Fit time=3.443 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=5805.351, BIC=5834.484, Fit time=4.821 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=6355.029, BIC=6374.451, Fit time=1.088 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=5805.349, BIC=5834.482, Fit time=13.715 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=5806.696, BIC=5840.684, Fit time=18.704 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=5808.571, BIC=5827.993, Fit time=4.267 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=5803.673, BIC=5832.806, Fit time=6.170 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=5823.494, BIC=5838.060, Fit time=3.457 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=5805.522, BIC=5839.510, Fit time=4.319 seconds
# Total fit time: 63.536 seconds
# Root Mean Square Error: 34.54543039289545
#            Symbol  High Price  Low Price  Average Price    Volume
# Date
# 2015-04-13    ITC      352.40     344.85         349.79   7261102
# 2015-04-15    ITC      358.60     351.40         355.68  11661496
# 2015-04-16    ITC      356.40     346.65         351.14   5243825
# 2015-04-17    ITC      353.25     347.70         351.60   5871559
# 2015-04-20    ITC      352.10     340.60         345.57   7517021
# .
# .
# .
#            Symbol  High Price  Low Price  Average Price    Volume
# Date
# 2019-04-10    ITC      296.55      293.5         295.11   5334642
# 2019-04-11    ITC      297.45      293.0         295.33  10764968
# 2019-04-12    ITC      307.40      295.6         302.46  21818291
#
# Displaying 10 out of 990 rows.
# Applying ARIMA Model on: ITC
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=5997.529, BIC=6021.806, Fit time=4.901 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=6648.499, BIC=6658.210, Fit time=0.094 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=6315.943, BIC=6335.364, Fit time=1.071 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=5996.057, BIC=6015.479, Fit time=3.106 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=5997.031, BIC=6021.308, Fit time=3.800 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=6635.317, BIC=6649.883, Fit time=0.312 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=5997.126, BIC=6021.403, Fit time=10.098 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=5997.336, BIC=6026.468, Fit time=14.949 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=6001.829, BIC=6016.395, Fit time=2.180 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=5996.738, BIC=6021.015, Fit time=3.426 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=5995.281, BIC=6024.414, Fit time=4.104 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=5996.323, BIC=6030.311, Fit time=5.325 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 0, 12); AIC=6586.890, BIC=6611.167, Fit time=2.383 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 2, 12); AIC=5996.399, BIC=6030.387, Fit time=13.339 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=5996.484, BIC=6035.327, Fit time=19.508 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=5996.226, BIC=6030.214, Fit time=6.753 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(0, 1, 1, 12); AIC=5995.904, BIC=6029.892, Fit time=9.975 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(0, 1, 1, 12); AIC=5997.875, BIC=6036.718, Fit time=8.459 seconds
# Total fit time: 113.784 seconds
# Root Mean Square Error: 17.164461314961518
#             Symbol  High Price  Low Price  Average Price  Volume
# Date
# 2015-04-13  MARUTI      3680.0    3642.75        3659.45  218690
# 2015-04-15  MARUTI      3729.0    3650.40        3697.64  232802
# 2015-04-16  MARUTI      3718.7    3662.25        3690.80  206305
# 2015-04-17  MARUTI      3682.9    3636.35        3660.63   99056
# 2015-04-20  MARUTI      3648.4    3584.60        3610.07  175033
# .
# .
# .
#             Symbol  High Price  Low Price  Average Price  Volume
# Date
# 2019-04-05  MARUTI     7143.95     7050.0        7102.19  729603
# 2019-04-08  MARUTI     7150.00     7044.7        7102.35  498374
# 2019-04-09  MARUTI     7235.00     7080.0        7155.98  741669
# 2019-04-10  MARUTI     7218.95     7144.6        7179.12  590107
#
# Displaying 10 out of 991 rows.
# Applying ARIMA Model on: MARUTI
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=11035.051, BIC=11059.328, Fit time=1.982 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=11681.612, BIC=11691.323, Fit time=0.094 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=11347.067, BIC=11366.488, Fit time=1.625 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=11034.070, BIC=11053.491, Fit time=1.530 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=11036.028, BIC=11060.305, Fit time=2.082 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=11634.035, BIC=11648.601, Fit time=0.429 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=11036.031, BIC=11060.308, Fit time=5.086 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=11036.317, BIC=11065.450, Fit time=20.235 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=11092.953, BIC=11107.519, Fit time=0.929 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=11035.101, BIC=11059.378, Fit time=2.068 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=11037.044, BIC=11066.177, Fit time=3.416 seconds
# Total fit time: 39.477 seconds
# Root Mean Square Error: 226.5332417447723
#            Symbol  High Price  Low Price  Average Price  Volume
# Date
# 2015-04-13    PVR       679.8      661.7         669.04   19009
# 2015-04-15    PVR       675.0      663.0         666.90   16250
# 2015-04-16    PVR       670.0      654.0         661.50   10192
# 2015-04-17    PVR       665.0      650.0         656.12   12223
# 2015-04-20    PVR       660.0      645.0         649.21    8804
# .
# .
# .
#            Symbol  High Price  Low Price  Average Price  Volume
# Date
# 2019-04-05    PVR     1682.05    1655.55        1667.41  281610
# 2019-04-08    PVR     1699.00    1669.70        1686.32  348832
# 2019-04-09    PVR     1687.00    1655.00        1671.04  255249
# 2019-04-10    PVR     1720.65    1670.00        1699.61  410044
#
# Displaying 10 out of 991 rows.
# Applying ARIMA Model on: PVR
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=8568.567, BIC=8592.844, Fit time=2.211 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=9144.716, BIC=9154.427, Fit time=0.094 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=8912.442, BIC=8931.863, Fit time=1.639 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=8567.819, BIC=8587.241, Fit time=1.438 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=8568.012, BIC=8592.289, Fit time=1.875 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=9136.379, BIC=9150.946, Fit time=0.521 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=8567.861, BIC=8592.138, Fit time=9.878 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=8569.743, BIC=8598.875, Fit time=15.434 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=8578.173, BIC=8592.739, Fit time=1.482 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=8568.374, BIC=8592.652, Fit time=1.520 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=8570.239, BIC=8599.371, Fit time=2.727 seconds
# Total fit time: 38.818 seconds
# Root Mean Square Error: 123.7182997418695
#            Symbol  High Price  Low Price  Average Price    Volume
# Date
# 2015-04-13   SBIN      288.50     283.35         285.79  11985436
# 2015-04-15   SBIN      294.45     285.95         290.52  17289500
# 2015-04-16   SBIN      294.25     286.50         290.52  15043998
# 2015-04-17   SBIN      294.90     289.20         292.12  16819018
# 2015-04-20   SBIN      293.35     284.85         289.82  13788536
# .
# .
# .
#            Symbol  High Price  Low Price  Average Price    Volume
# Date
# 2019-04-08   SBIN      319.25      311.1         314.81  17394139
# 2019-04-09   SBIN      315.70      308.1         311.80  25556039
# 2019-04-10   SBIN      317.05      310.0         313.54  19237974
# 2019-04-11   SBIN      315.40      308.7         312.15  14897935
#
# Displaying 10 out of 991 rows.
# Applying ARIMA Model on: SBIN
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=5633.361, BIC=5657.638, Fit time=4.313 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=6197.370, BIC=6207.081, Fit time=0.094 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=5931.304, BIC=5950.726, Fit time=1.046 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=5633.522, BIC=5652.944, Fit time=2.756 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=5625.968, BIC=5655.100, Fit time=5.644 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 0, 12); AIC=5924.768, BIC=5949.045, Fit time=1.664 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=5633.098, BIC=5667.086, Fit time=16.545 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=6142.210, BIC=6161.631, Fit time=0.469 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 1, 2, 12); AIC=5627.769, BIC=5666.612, Fit time=19.473 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=5625.325, BIC=5649.602, Fit time=3.830 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 1, 1, 12); AIC=5680.840, BIC=5700.261, Fit time=3.287 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=5626.133, BIC=5655.265, Fit time=5.285 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=5624.966, BIC=5658.954, Fit time=7.267 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=5633.938, BIC=5663.070, Fit time=4.270 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(2, 1, 1, 12); AIC=5627.240, BIC=5666.083, Fit time=20.149 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 0, 12); AIC=5900.894, BIC=5930.026, Fit time=7.730 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=5633.868, BIC=5672.711, Fit time=20.307 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 0, 12); AIC=6101.710, BIC=6125.987, Fit time=2.698 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(2, 1, 2, 12); AIC=5629.178, BIC=5672.877, Fit time=24.676 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=5626.807, BIC=5665.650, Fit time=10.315 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(1, 1, 1, 12); AIC=5626.930, BIC=5665.773, Fit time=10.759 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(1, 1, 1, 12); AIC=5621.750, BIC=5665.449, Fit time=17.779 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(0, 1, 1, 12); AIC=5631.190, BIC=5670.033, Fit time=9.562 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(2, 1, 1, 12); AIC=5625.507, BIC=5674.061, Fit time=24.730 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(1, 1, 0, 12); AIC=5870.169, BIC=5909.013, Fit time=8.975 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(1, 1, 2, 12); AIC=5632.638, BIC=5681.193, Fit time=37.903 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(0, 1, 0, 12); AIC=6080.494, BIC=6114.482, Fit time=5.421 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(2, 1, 2, 12); AIC=5626.132, BIC=5679.541, Fit time=35.179 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(1, 1, 1, 12); AIC=5620.127, BIC=5668.681, Fit time=13.130 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=5618.362, BIC=5662.060, Fit time=10.205 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=5627.040, BIC=5661.028, Fit time=4.430 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=5628.106, BIC=5666.949, Fit time=8.786 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(2, 1, 1, 12); AIC=5620.463, BIC=5669.017, Fit time=29.600 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(1, 1, 0, 12); AIC=5867.757, BIC=5906.601, Fit time=8.443 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=5628.254, BIC=5676.808, Fit time=28.499 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(0, 1, 0, 12); AIC=6048.315, BIC=6082.302, Fit time=2.870 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(2, 1, 2, 12); AIC=5619.762, BIC=5673.172, Fit time=32.506 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=5628.054, BIC=5666.897, Fit time=8.054 seconds
# Total fit time: 459.189 seconds
# Root Mean Square Error: 34.61767902339631

# %%
print(rmseStock)
for stock in rmseStock:
    if stock == 'BIOCON':
        rmseStock[stock] = (rmseStock[stock] / 627.68) * 100
    elif stock == 'BRITANNIA':
        rmseStock[stock] = (rmseStock[stock] / 2970.17) * 100
    elif stock == 'COALINDIA':
        rmseStock[stock] = (rmseStock[stock] / 240.90) * 100
    elif stock == 'EICHERMOT':
        rmseStock[stock] = (rmseStock[stock] / 21131.52) * 100
    elif stock == 'HEIDELBERG':
        rmseStock[stock] = (rmseStock[stock] / 177.81) * 100
    elif stock == 'ICICIBANK':
        rmseStock[stock] = (rmseStock[stock] / 395.63) * 100
    elif stock == 'ITC':
        rmseStock[stock] = (rmseStock[stock] / 302.46) * 100
    elif stock == 'MARUTI':
        rmseStock[stock] = (rmseStock[stock] / 7179.12) * 100
    elif stock == 'PVR':
        rmseStock[stock] = (rmseStock[stock] / 1699.61) * 100
    elif stock == 'SBIN':
        rmseStock[stock] = (rmseStock[stock] / 312.15) * 100
   
rmseStock['zReference'] = 100
    
plt.bar(list(rmseStock.keys()), rmseStock.values(), color='tomato')
plt.title("Percentage RMS Error", fontsize = 18)
# Out:
# {'BIOCON': 10.760898111763032, 'BRITANNIA': 104.02291331561547, 'COALINDIA': 20.917941232112238, 'EICHERMOT': 2110.138974384907, 'HEIDELBERG': 27.680386431353806, 'ICICIBANK': 34.54543039289545, 'ITC': 17.164461314961518, 'MARUTI': 226.5332417447723, 'PVR': 123.7182997418695, 'SBIN': 34.61767902339631}
# Text(0.5, 1.0, 'Percentage RMS Error')

# %% [markdown]
# ## Inference:

# %% [markdown]
# #### Pros:
#     - Trend identification
#     - Performance better than LR
#     - Error (RMS) lies in [2-10]%
#     - Dividend doesn't affect the predcition and its clos enough to the actual value.
#
# #### Cons:
#     - Scope for improvement.
#     - Statistical model rather than Machine Learning model.
#     -
